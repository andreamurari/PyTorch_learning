# %%
import torch

# %%
x = torch.rand(5, 3)
print(x)
# Out:
# tensor([[0.3935, 0.1504, 0.5496],
#         [0.0975, 0.2474, 0.8735],
#         [0.1109, 0.8051, 0.1248],
#         [0.9555, 0.9559, 0.2282],
#         [0.3659, 0.5401, 0.2527]])

# %%
torch.cuda.is_available()
# Out:
# False
